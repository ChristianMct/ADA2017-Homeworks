# %%
import pandas as pd
import json
import json, pprint, re, datetime
import mwparserfromhell
import re
import calendar

# %%
data= "../datasets/battle-fields-0.json"
df= pd.read_json(data)
df['start_day']='empty'
df['start_month']='empty'
df['start_year']='empty'
df['end_day']='empty'
df['end_month']='empty'
df['end_year']='empty'

# %%
df
# Out:
#             format        id  \
# 0      text/x-wiki      3730
# 1      text/x-wiki      4160
# 2      text/x-wiki      4005
# 3      text/x-wiki      4503
# 4      text/x-wiki      4605
# 5      text/x-wiki      4050
# 6      text/x-wiki      4049
# 7      text/x-wiki      4283
# 8      text/x-wiki      4812
# 9      text/x-wiki      4806
# 10     text/x-wiki      4928
# 11     text/x-wiki      4954
# 12     text/x-wiki      4615
# 13     text/x-wiki      4977
# 14     text/x-wiki      3793
# 15     text/x-wiki      4975
# 16     text/x-wiki      4984
# 17     text/x-wiki      4985
# 18     text/x-wiki      4987
# 19     text/x-wiki      4978
# 20     text/x-wiki      4284
# 21     text/x-wiki      5003
# 22     text/x-wiki      4849
# 23     text/x-wiki      5008
# 24     text/x-wiki      4606
# 25     text/x-wiki      4356
# 26     text/x-wiki      5013
# 27     text/x-wiki     11775
# 28     text/x-wiki      4563
# 29     text/x-wiki     31570
# ...            ...       ...
# 27225  text/x-wiki  55670278
# 27226  text/x-wiki  55670282
# 27227  text/x-wiki  55670294
# 27228  text/x-wiki  55670319
# 27229  text/x-wiki  55670347
# 27230  text/x-wiki  55670353
# 27231  text/x-wiki  55670372
# 27232  text/x-wiki  55670527
# 27233  text/x-wiki  55670537
# 27234  text/x-wiki  55670297
# 27235  text/x-wiki  55543269
# 27236  text/x-wiki  55672342
# 27237  text/x-wiki  55672353
# 27238  text/x-wiki  55672356
# 27239  text/x-wiki  55674651
# 27240  text/x-wiki  55672367
# 27241  text/x-wiki  55677546
# 27242  text/x-wiki  55681997
# 27243  text/x-wiki  55689959
# 27244  text/x-wiki  55690992
# 27245  text/x-wiki  55699012
# 27246  text/x-wiki  55699128
# 27247  text/x-wiki  55581035
# 27248  text/x-wiki  55699167
# 27249  text/x-wiki  55682438
# 27250  text/x-wiki  55685610
# 27251  text/x-wiki  55063600
# 27252  text/x-wiki  55573803
# 27253  text/x-wiki  52019122
# 27254  text/x-wiki  55539282
#
#                                                  infobox     model     rev_id  \
# 0                                {'error': 'no infobox'}  wikitext  801789471
# 1      {'strength1': '
# ', 'casualties2': '
# ', 'campai...  wikitext  804638880
# 2      {'strength1': 'Approximately 22,000 [[Legionar...  wikitext  808453877
# 3      {'strength1': ' <small>'''Modern estimates:'''...  wikitext  808420865
# 4                                {'error': 'no infobox'}  wikitext  529156097
# 5      {'strength1': '62,000 men<ref>All statistics t...  wikitext  804640597
# 6      {'strength1': '52,000 men,<ref>Statistics take...  wikitext  804640502
# 7      {'strength1': '47,561<ref name=Moran/>{{rp|36}...  wikitext  807247633
# 8                                {'error': 'no infobox'}  wikitext   17776769
# 9      {'casualties2': '6,400 dead <br />7 ships dest...  wikitext  806376581
# 10     {'strength1': '2,700
# ', 'casualties2': '~250
# '...  wikitext  749848327
# 11                               {'error': 'no infobox'}  wikitext   17776761
# 12     {'strength1': ' Modern estimates range from 6,...  wikitext  808408414
# 13                               {'error': 'no infobox'}  wikitext  528758839
# 14     {'strength1': ' 7,500–12,000
# ', 'casualties2':...  wikitext  807746235
# 15     {'strength1': 'unknown
# ', 'casualties2': 'unkn...  wikitext  798644341
# 16                               {'error': 'no infobox'}  wikitext   15903231
# 17                               {'error': 'no infobox'}  wikitext   51669158
# 18                               {'error': 'no infobox'}  wikitext  777886127
# 19     {'casualties2': ' less than 1,000 killed<ref>G...  wikitext  804639135
# 20     {'casualties2': ' {{Unbulleted list
# |'''1,129,...  wikitext  808452900
# 21     {'strength1': '6,000–8,000{{sfn|Verbruggen|199...  wikitext  808330844
# 22     {'strength1': ' 104,256 ("present for duty")<r...  wikitext  807742113
# 23     {'strength1': ' 250 [[galley]]s<br />16,000 in...  wikitext  808450930
# 24     {'strength1': '13 [[ships of the line]], 1 [[f...  wikitext  804645130
# 25     {'strength1': ' '''Total''': 73,000{{sfn|Hofsc...  wikitext  807711887
# 26     {'campaign': '
# ', 'strength1': '80,000 armed w...  wikitext  803460684
# 27     {'strength1': '96,000 troops (40,000 German, 5...  wikitext  807363308
# 28     {'strength1': ' '''Total: 151 combat ships'''<...  wikitext  808515699
# 29     {'strength1': ' One ''Panzerschiff'' (heavy cr...  wikitext  806482468
# ...                                                  ...       ...        ...
# 27225                            {'error': 'no infobox'}  wikitext  807942477
# 27226                            {'error': 'no infobox'}  wikitext  807942619
# 27227                            {'error': 'no infobox'}  wikitext  807942960
# 27228                            {'error': 'no infobox'}  wikitext  807943408
# 27229                            {'error': 'no infobox'}  wikitext  807943922
# 27230                            {'error': 'no infobox'}  wikitext  807945052
# 27231                            {'error': 'no infobox'}  wikitext  807944344
# 27232                            {'error': 'no infobox'}  wikitext  807948025
# 27233                            {'error': 'no infobox'}  wikitext  807948232
# 27234                            {'error': 'no infobox'}  wikitext  807943038
# 27235  {'combatants_header': '
# ', 'notes': '
# ', 'ca...  wikitext  808605510
# 27236                            {'error': 'no infobox'}  wikitext  807986245
# 27237                            {'error': 'no infobox'}  wikitext  807986324
# 27238                            {'error': 'no infobox'}  wikitext  807986377
# 27239                            {'error': 'no infobox'}  wikitext  808028308
# 27240                            {'error': 'no infobox'}  wikitext  807986466
# 27241                            {'error': 'no infobox'}  wikitext  808079004
# 27242                            {'error': 'no infobox'}  wikitext  808173852
# 27243                            {'error': 'no infobox'}  wikitext  808323333
# 27244                            {'error': 'no infobox'}  wikitext  808344237
# 27245                            {'error': 'no infobox'}  wikitext  808509102
# 27246                            {'error': 'no infobox'}  wikitext  808513823
# 27247                            {'error': 'no infobox'}  wikitext  808364366
# 27248                            {'error': 'no infobox'}  wikitext  808513218
# 27249  {'strength1': ' 9,500{{sfn|Bodart|1916|p=85}}{...  wikitext  808214673
# 27250  {'strength1': ' Unknown
# ', 'casualties2': ' Un...  wikitext  808347052
# 27251                            {'error': 'no infobox'}  wikitext  806359871
# 27252  {'casualties2': ' 300+ killed <small>(SAA clai...  wikitext  808628205
# 27253  {'notes': '{{Note label|date|a}} The Iraqi Gov...  wikitext  808453301
# 27254                            {'error': 'no infobox'}  wikitext  807421165
#
#                                                    title start_day  \
# 0                  Battle of Adrianople (disambiguation)     empty
# 1                                  Battle of Lostwithiel     empty
# 2                                    Battle of Pharsalus     empty
# 3                                     Battle of Poitiers     empty
# 4                                  Battle of Aboukir Bay     empty
# 5                                    Battle of Ramillies     empty
# 6                                     Battle of Blenheim     empty
# 7                                      Battle of Peleliu     empty
# 8                                    Battle of Zarnowiec     empty
# 9                                     Battle of Marathon     empty
# 10                                    Battle of Świecino     empty
# 11                                     Battle of Schwetz     empty
# 12                                   Battle of Agincourt     empty
# 13                                Battle of Adrianopolis     empty
# 14                              Battle of Bosworth Field     empty
# 15                                     Battle of Abritus     empty
# 16                                 Battle of Ardrianople     empty
# 17                                    Battle of Ardennes     empty
# 18                                  Battle of El Alamein     empty
# 19                                 Battle of Berestechko     empty
# 20                                  Battle of Stalingrad     empty
# 21                                    Battle of Bouvines     empty
# 22                                  Battle of Gettysburg     empty
# 23                                      Battle of Actium     empty
# 24                                    Battle of the Nile     empty
# 25                                    Battle of Waterloo     empty
# 26                                        Battle of Adwa     empty
# 27                            First Battle of El Alamein     empty
# 28                                     Battle of Jutland     empty
# 29                             Battle of the River Plate     empty
# ...                                                  ...       ...
# 27225                   First Battle of Al-Shaykh Maskin     empty
# 27226                  Second Battle of Al-Shaykh Maskin     empty
# 27227                First Battle of the Shaer gas field     empty
# 27228                Third Battle of the Shaer gas field     empty
# 27229                        Battle of Maarrat al-Nu'man     empty
# 27230                  Second Battle of Maarat al-Nu'man     empty
# 27231                  Battle of Maarat al-Nu'man (2016)     empty
# 27232                          May 2012 battle of Rastan     empty
# 27233                            Battle of Rastan (2012)     empty
# 27234               Second Battle of the Shaer gas field     empty
# 27235                            Battle of Kirkuk (2017)     empty
# 27236               Battle of Al-Shaykh Maskin (2015-16)     empty
# 27237                       Siege of Wadi Deif (2012-13)     empty
# 27238           Battle of Rastan (January-February 2012)     empty
# 27239                         Category:Battle of Lepanto     empty
# 27240  Battle of the Shaer gas field (October-Novembe...     empty
# 27241               Battle of Donetsk Airport (May 2014)     empty
# 27242                           Siege of Mytilene (1462)     empty
# 27243                            Battle of Turjak Castle     empty
# 27244  Category:Scottish deaths at the Battle of Dunb...     empty
# 27245                                 Battle of Orahovac     empty
# 27246     Battle of Deir ez-Zor (September 2017–present)     empty
# 27247  Wikipedia:WikiProject Military history/Assessm...     empty
# 27248    Battle of Deir ez-Zor (September-November 2017)     empty
# 27249                                   Battle of Kempen     empty
# 27250                          Siege of Babylon Fortress     empty
# 27251             Order of battle at the Battle of Genoa     empty
# 27252    Battle of Deir ez-Zor (September–November 2017)     empty
# 27253                        Battle of Mosul (2016–2017)     empty
# 27254  Order of battle at the Battle of the Hyères Is...     empty
#
#       start_month start_year end_day end_month end_year
# 0           empty      empty   empty     empty    empty
# 1           empty      empty   empty     empty    empty
# 2           empty      empty   empty     empty    empty
# 3           empty      empty   empty     empty    empty
# 4           empty      empty   empty     empty    empty
# 5           empty      empty   empty     empty    empty
# 6           empty      empty   empty     empty    empty
# 7           empty      empty   empty     empty    empty
# 8           empty      empty   empty     empty    empty
# 9           empty      empty   empty     empty    empty
# 10          empty      empty   empty     empty    empty
# 11          empty      empty   empty     empty    empty
# 12          empty      empty   empty     empty    empty
# 13          empty      empty   empty     empty    empty
# 14          empty      empty   empty     empty    empty
# 15          empty      empty   empty     empty    empty
# 16          empty      empty   empty     empty    empty
# 17          empty      empty   empty     empty    empty
# 18          empty      empty   empty     empty    empty
# 19          empty      empty   empty     empty    empty
# 20          empty      empty   empty     empty    empty
# 21          empty      empty   empty     empty    empty
# 22          empty      empty   empty     empty    empty
# 23          empty      empty   empty     empty    empty
# 24          empty      empty   empty     empty    empty
# 25          empty      empty   empty     empty    empty
# 26          empty      empty   empty     empty    empty
# 27          empty      empty   empty     empty    empty
# 28          empty      empty   empty     empty    empty
# 29          empty      empty   empty     empty    empty
# ...           ...        ...     ...       ...      ...
# 27225       empty      empty   empty     empty    empty
# 27226       empty      empty   empty     empty    empty
# 27227       empty      empty   empty     empty    empty
# 27228       empty      empty   empty     empty    empty
# 27229       empty      empty   empty     empty    empty
# 27230       empty      empty   empty     empty    empty
# 27231       empty      empty   empty     empty    empty
# 27232       empty      empty   empty     empty    empty
# 27233       empty      empty   empty     empty    empty
# 27234       empty      empty   empty     empty    empty
# 27235       empty      empty   empty     empty    empty
# 27236       empty      empty   empty     empty    empty
# 27237       empty      empty   empty     empty    empty
# 27238       empty      empty   empty     empty    empty
# 27239       empty      empty   empty     empty    empty
# 27240       empty      empty   empty     empty    empty
# 27241       empty      empty   empty     empty    empty
# 27242       empty      empty   empty     empty    empty
# 27243       empty      empty   empty     empty    empty
# 27244       empty      empty   empty     empty    empty
# 27245       empty      empty   empty     empty    empty
# 27246       empty      empty   empty     empty    empty
# 27247       empty      empty   empty     empty    empty
# 27248       empty      empty   empty     empty    empty
# 27249       empty      empty   empty     empty    empty
# 27250       empty      empty   empty     empty    empty
# 27251       empty      empty   empty     empty    empty
# 27252       empty      empty   empty     empty    empty
# 27253       empty      empty   empty     empty    empty
# 27254       empty      empty   empty     empty    empty
#
# [27255 rows x 12 columns]

# %%
for i in range(759,1196):
    if 'error' in df.infobox[i]:
        df.start_day[i]='noinfo'
        df.end_day[i]='noinfo'
        df.start_month[i]='noinfo'
        df.end_month[i]='noinfo'
        df.start_year[i]='noinfo'
        df.end_year[i]='noinfo'
    elif 'date' not in df.infobox[i].keys():
        df.start_day[i]='nodate'
        df.end_day[i]='nodate'
        df.start_month[i]='nodate'
        df.end_month[i]='nodate'
        df.start_year[i]='nodate'
        df.end_year[i]='nodate'
    elif re.search('\sBC\s',df.infobox[i]['date']):
        if re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\sBC',df.infobox[i]['date']):
            df.start_day[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\sBC',df.infobox[i]['date']).group(1))
            month=re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\sBC',df.infobox[i]['date']).group(2)
            df.start_month[i]=datetime.datetime.strptime(month[:3], '%b').month
            df.start_year[i]=-int(re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\sBC',df.infobox[i]['date']).group(3))
            df.end_day[i]=df.start_day[i]
            df.end_month[i]=df.start_month[i]
            df.end_year[i]=df.start_year[i]
        if re.search('(\w{3,9}),\s(\d{1,4})\sBC',df.infobox[i]['date']):
            df.start_day[i]=0
            month=re.search('(\w{3,9}),\s(\d{1,4})\sBC',df.infobox[i]['date']).group(1)
            df.start_month[i]=datetime.datetime.strptime(month[:3], '%b').month
            df.start_year[i]=-int(re.search('(\w{3,9}),\s(\d{1,4})\sBC',df.infobox[i]['date']).group(2))
            df.end_day[i]=df.start_day[i]
            df.end_month[i]=df.start_month[i]
            df.end_year[i]=df.start_year[i]
        elif re.search('(\w{3,9})\s(\d{1,2})\sand\s\d{1,2},\s(\d{1,4})\sBC',df.infobox[i]['date']):
            df.start_day[i]=int(re.search('(\w{3,9})\s(\d{1,2})\sand\s\d{1,2},\s(\d{1,4})\sBC',df.infobox[i]['date']).group(2))
            stmonth=re.search('(\w{3,9})\s(\d{1,2})\sand\s\d{1,2},\s(\d{1,4})\sBC',df.infobox[i]['date']).group(1)
            df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
            df.start_year[i]=-int(re.search('(\w{3,9})\s(\d{1,2})\sand\s\d{1,2},\s(\d{1,4})\sBC',df.infobox[i]['date']).group(3))
            df.end_day[i]=df.start_day[i]
            enmonth=stmonth
            df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
            df.end_year[i]=df.start_year[i]
        elif re.search('^(\w{3,9})/(\w{3,9})\s.*,\s(\d{1,4})\sBC',df.infobox[i]['date']):
            df.start_day[i]=0
            stmonth=re.search('(\w{3,9})/(\w{3,9})\s.*,\s(\d{1,4})\sBC',df.infobox[i]['date']).group(1)
            df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
            df.start_year[i]=-int(re.search('(\w{3,9})/(\w{3,9})\s.*,\s(\d{1,4})\sBC',df.infobox[i]['date']).group(3))
            df.end_day[i]=0
            enmonth=re.search('(\w{3,9})/(\w{3,9})\s.*,\s(\d{1,4})\sBC',df.infobox[i]['date']).group(2)
            df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
            df.end_year[i]=df.start_year[i]
        elif re.search('(\d{1,4})\sBC',df.infobox[i]['date']):
            df.start_day[i]=0
            df.start_month[i]=0
            df.start_year[i]=-int(re.search('(\d{1,4})\sBC',df.infobox[i]['date']).group(1))
            df.end_day[i]=0
            df.end_month[i]=0
            df.end_year[i]=df.start_year[i]  
            
    elif re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(1))
        stmonth=re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(2)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(3))
        df.end_day[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(4))
        enmonth=re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(5)
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(6))
    elif re.search('(\d{1,2})\s(\w{3,9})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(1))
        stmonth=re.search('(\d{1,2})\s(\w{3,9})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(2)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(5))
        df.end_day[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(3))
        enmonth=re.search('(\d{1,2})\s(\w{3,9})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(4)
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(5))
    elif re.search('(\d{1,2})–(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=int(re.search('(\d{1,2})–(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(1))
        stmonth=re.search('(\d{1,2})–(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(3)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\d{1,2})–(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(4))
        df.end_day[i]=int(re.search('(\d{1,2})–(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(2))
        enmonth=re.search('(\d{1,2})–(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(3)
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=int(re.search('(\d{1,2})–(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(4))
    elif re.search('late\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=0
        df.start_month[i]=0
        df.start_year[i]=int(re.search('late\s(\d{1,4})',df.infobox[i]['date']).group(1))
        df.end_day[i]=df.start_day[i]
        df.end_month[i]=0
        df.end_year[i]=df.start_year[i]
    elif re.search('(\w{3,9})\s(\d{1,2})–(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=int(re.search('(\w{3,9})\s(\d{1,2})–(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(2))
        stmonth=re.search('(\w{3,9})\s(\d{1,2})–(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(1)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\w{3,9})\s(\d{1,2})–(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(4))
        df.end_day[i]=int(re.search('(\w{3,9})\s(\d{1,2})–(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(3))
        enmonth=stmonth
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=int(re.search('(\w{3,9})\s(\d{1,2})–(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(4))
    elif re.search('(\w{3,9})\s(\d{1,2})\s–\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=int(re.search('(\w{3,9})\s(\d{1,2})\s–\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(2))
        stmonth=re.search('(\w{3,9})\s(\d{1,2})\s–\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(1)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\w{3,9})\s(\d{1,2})\s–\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(5))
        df.end_day[i]=int(re.search('(\w{3,9})\s(\d{1,2})\s–\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(4))
        enmonth=re.search('(\w{3,9})\s(\d{1,2})\s–\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(3)
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=int(re.search('(\w{3,9})\s(\d{1,2})\s–\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(5))
    elif re.search('(\w{3,9})\s(\d{1,4})\s–\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=0
        stmonth=re.search('(\w{3,9})\s(\d{1,4})\s–\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(1)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\w{3,9})\s(\d{1,4})\s–\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(2))
        df.end_day[i]=0
        enmonth=re.search('(\w{3,9})\s(\d{1,4})\s–\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(3)
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=int(re.search('(\w{3,9})\s(\d{1,4})\s–\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(4))
    elif re.search('(\d{1,2})\sand\s\d{1,2}\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=int(re.search('(\d{1,2})\sand\s\d{1,2}\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(1))
        stmonth=re.search('(\d{1,2})\sand\s\d{1,2}\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(2)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\d{1,2})\sand\s\d{1,2}\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(3))
        df.end_day[i]=int(re.search('(\d{1,2})\sand\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(2))
        enmonth=stmonth
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=df.start_year[i]
    elif re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(1))
        stmonth=re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(2)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(3))
        df.end_day[i]=df.start_day[i]
        enmonth=stmonth
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=df.start_year[i]
    elif re.search('\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})\sAD',df.infobox[i]['date']):
        df.start_day[i]=int(re.search('\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})\sAD',df.infobox[i]['date']).group(2))
        stmonth=re.search('\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})\sAD',df.infobox[i]['date']).group(1)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('\s(\w{3,9})\s(\d{1,2}),\s(\d{1,4})\sAD',df.infobox[i]['date']).group(3))
        df.end_day[i]=df.start_day[i]
        enmonth=stmonth
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=df.start_year[i]  
    elif re.search('(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=int(re.search('(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(2))
        stmonth=re.search('(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(1)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\w{3,9})\s(\d{1,2}),\s(\d{1,4})',df.infobox[i]['date']).group(3))
        df.end_day[i]=df.start_day[i]
        enmonth=stmonth
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=df.start_year[i]    
    elif re.search('(\w{3,9})\sor\s(\w{3,9}),\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=0
        stmonth=re.search('(\w{3,9})\sor\s(\w{3,9}),\s(\d{1,4})',df.infobox[i]['date']).group(1)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('(\w{3,9})\sor\s(\w{3,9}),\s(\d{1,4})',df.infobox[i]['date']).group(3))
        df.end_day[i]=df.start_day[i]
        enmonth=stmonth
        df.end_month[i]=datetime.datetime.strptime(enmonth[:3], '%b').month
        df.end_year[i]=df.start_year[i]
    elif re.search('(\d{1,4})\sor\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=0
        df.start_month[i]=0
        df.start_year[i]=int(re.search('(\d{1,4})\sor\s(\d{1,4})',df.infobox[i]['date']).group(1))
        df.end_day[i]=df.start_day[i]
        df.end_month[i]=0
        df.end_year[i]=df.start_year[i]
    elif re.search('^(\w{3,9}})\s(\d{1,4})',df.infobox[i]['date']):
        df.start_day[i]=0
        stmonth=re.search('^(\w{3,9}})\s(\d{1,4})',df.infobox[i]['date']).group(1)
        df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
        df.start_year[i]=int(re.search('^(\w{3,9}})\s(\d{1,4})',df.infobox[i]['date']).group(2))
        df.end_day[i]=df.start_day[i]
        df.end_month[i]=df.start_month[i]
        df.end_year[i]=df.start_year[i]
    else:
        df.start_day[i]='emptyTreated'
# Out:
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:68: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:172: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:113: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:116: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:119: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/envs/ada/lib/python3.5/site-packages/ipykernel/__main__.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-274-0f8609c41d2c> in <module>()
#     113         df.start_day[i]=0
#     114         stmonth=re.search('(\w{3,9})\s(\d{1,4})\s–\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(1)
# --> 115         df.start_month[i]=datetime.datetime.strptime(stmonth[:3], '%b').month
#     116         df.start_year[i]=int(re.search('(\w{3,9})\s(\d{1,4})\s–\s(\w{3,9})\s(\d{1,4})',df.infobox[i]['date']).group(2))
#     117         df.end_day[i]=0
#
# /anaconda3/envs/ada/lib/python3.5/_strptime.py in _strptime_datetime(cls, data_string, format)
#     508     """Return a class cls instance based on the input string and the
#     509     format string."""
# --> 510     tt, fraction = _strptime(data_string, format)
#     511     tzname, gmtoff = tt[-2:]
#     512     args = tt[:6] + (fraction,)
#
# /anaconda3/envs/ada/lib/python3.5/_strptime.py in _strptime(data_string, format)
#     341     if not found:
#     342         raise ValueError("time data %r does not match format %r" %
# --> 343                          (data_string, format))
#     344     if len(data_string) != found.end():
#     345         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data 'Lat' does not match format '%b'

# %%
df.start_day[4845]=0
df.start_year

# %%
re.search("(\d)+\s(.*)(\d{4})<",df.infobox[7]['date']).group(3)
# Out:
# '1704'

# %%
re.search('(\d{1,2})\s(\w{3,9})\s–\s(\d{1,2})\s(\w{3,9})\s(\d{1,4})',df.infobox[33]['date']).group(1)
# Out:
# '23'

# %%
a=-int(re.search('\w{3,9}\sor\s\w{3,9},\s(\d{1,4})','July or August, 251').group(1))

# %%
df.infobox[3822].keys()
# Out:
# dict_keys(['strength1', 'casualties2', 'strength2', 'conflict', 'commander2', 'commander1', 'image', '55tu55h55\ndate', 'combatant1', 'place', 'casualties1', 'result', 'combatant2'])

# %%
if 'date' not in df.infobox[3822].keys():
    print('NotIn')
# Out:
# NotIn

# %%
re.search('(\w{3,9})\s(\d{1,4})\s–\s(\w{3,9})\s(\d{1,4})',df.infobox[27250]['date']).group(0)
# Out:
# 'May 640 – December 640'

# %%
df.end_month[758]
# Out:
# 'empty'

# %%
index=len(df['start_day'])-1
while index>0:
    if df['start_day'][index] != 'empty':
        print(index)
        break
    index-=1
# Out:
# 5406

# %%
index=44
while index<len(df['start_day']):
    if df['start_day'][index] == 'empty':
        print(index)
        break
    index+=1
# Out:
# 5407

# %%
df.start_year[5406]
# Out:
# 'empty'

# %%
re.search('^(\w{3,9})/(\w{3,9})\s.*,\s(\d{1,4})\sBC',df.infobox[112]['date'])

# %%
df['start_day'].values_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-268-af16f24bbba2> in <module>()
# ----> 1 df['start_day'].values_count()
#
# /anaconda3/envs/ada/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'values_count'

# %%
df.infobox[1195]
# Out:
# {'caption': ' Masada National Park\n',
#  'casualties1': ' 960 dead, 7 captured (2 women, 5 children)\n',
#  'casualties2': ' Unknown\n',
#  'closest_city': ' [[Arad, Israel|Arad]]\n',
#  'combatant1': ' Jewish [[Sicarii]]\n',
#  'combatant2': ' [[Roman Empire]]\n',
#  'commander1': " [[Eleazar ben Ya'ir]]\n",
#  'commander2': ' [[Lucius Flavius Silva]]\n',
#  'conflict': ' Siege of Masada\n',
#  'date': ' Late 72 – early 73 (traditional date) <br/> Late 73 – early 74 CE (proposed date)<ref>{{cite journal |jstor=20186870 |title=Dating the Siege of Masada |last=Campbell |first=Duncan B. |year=1988 |journal=Zeitschrift für Papyrologie und Epigraphik |volume=73 |issue=1988 |pages=156–158 }}</ref><ref>{{cite journal |jstor=20187128 |title=The Date of the Fall of Masada: The Evidence of the Masada Papyri |last=Cotton |first=Hannah M. |year=1989 |journal=Zeitschrift für Papyrologie und Epigraphik |volume=78 |issue=1989 |pages=157–162 }}</ref>\n',
#  'image': ' [[File:Israel-2013-Aerial 21-Masada.jpg|300px]]\n',
#  'partof': ' the [[First Jewish–Roman War]]\n',
#  'place': ' Masada, [[Israel]]<br/>{{Coord|31|18|56|N|35|21|13|E|type:event}}\n',
#  'result': ' Roman victory\n',
#  'strength1': ' 967, including non-combatants\n',
#  'strength2': ' [[Legio X Fretensis]] 4,800<br />Auxiliaries and slaves 4,000–10,000\n',
#  'territory': '\n'}

# %%
re.search('(\d{1,4})\sBC',df.infobox[3667]['date']).group(1)
# Out:
# '207'

# %%
df.start_day[3858]
# Out:
# 3

# %%
df.loc['start_day'=='emptyTreated'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/envs/ada/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2521             try:
# -> 2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-278-58246a8e5dd0> in <module>()
# ----> 1 df.loc['start_day'=='emptyTreated'].count()
#
# /anaconda3/envs/ada/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# /anaconda3/envs/ada/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1625         # fall thru to straight lookup
#    1626         self._has_valid_type(key, axis)
# -> 1627         return self._get_label(key, axis=axis)
#    1628
#    1629
#
# /anaconda3/envs/ada/lib/python3.5/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     143             raise IndexingError('no slices here, handle elsewhere')
#     144
# --> 145         return self.obj._xs(label, axis=axis)
#     146
#     147     def _get_loc(self, key, axis=None):
#
# /anaconda3/envs/ada/lib/python3.5/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    2342                                                       drop_level=drop_level)
#    2343         else:
# -> 2344             loc = self.index.get_loc(key)
#    2345
#    2346             if isinstance(loc, np.ndarray):
#
# /anaconda3/envs/ada/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2522                 return self._engine.get_loc(key)
#    2523             except KeyError:
# -> 2524                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2525
#    2526         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: False

# %%
df['start_day'].value_counts()
# Out:
# empty           21849
# noinfo           2859
# emptyTreated      540
# 0                 172
# 1                  78
# 6                  73
# 25                 69
# 10                 67
# 19                 67
# 8                  66
# 14                 65
# 2                  65
# 11                 65
# 15                 64
# 27                 63
# 24                 63
# 29                 62
# 17                 61
# 3                  61
# 28                 60
# 20                 60
# 9                  60
# 26                 58
# 13                 57
# 18                 56
# 23                 56
# 21                 54
# 22                 54
# 5                  53
# 16                 52
# 12                 49
# 4                  49
# 7                  47
# 30                 46
# 31                 29
# nodate              3
# 71                  1
# 73                  1
# 41                  1
# Name: start_day, dtype: int64

# %%
5407-2859-540
# Out:
# 2008
